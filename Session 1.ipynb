# %%
print("Hello,World")
# Out:
# Hello,World

# %%
x=2

# %%
x
# Out:
# 2

# %%
x=x+2
print(x)
# Out:
# 10

# %%
x
# Out:
# 4

# %%
x+5
# Out:
# 15

# %%
x="sagan"

# %%
x
# Out:
# 'sagan'

# %%
x+str(2)
# Out:
# 'sagan2'

# %%
y=3
x=y+3
print(x)
# Out:
# 6

# %%
x = 5
if x < 10:
    print('Smaller')
if x > 10:
    print('Bigger')
print('Finish')
# Out:
# Smaller
# Finish

# %%
2/3
# Out:
# 0.6666666666666666

# %%
run simple.py
# Out:
# 12

# %%
#Rocket BlastOff serial
n=15
while n>9:
    print(n)
    n=n-1
print('Ignitions On')
while n>2:
    print(n)
    n=n-1
print('Ready to takeoff')
while n>0:
    print(n)
    n=n-1
print('BlastOff!!')
# Out:
# 15
# 14
# 13
# 12
# 11
# 10
# Ignitions On
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# Ready to takeoff
# 2
# 1
# BlastOff!!

# %%
n=50
while n>0:
    print(n)
    n=n/2
print('BlastOff!!')
# Out:
# 50
# 25.0
# 12.5
# 6.25
# 3.125
# 1.5625
# 0.78125
# 0.390625
# 0.1953125
# 0.09765625
# 0.048828125
# 0.0244140625
# 0.01220703125
# 0.006103515625
# 0.0030517578125
# 0.00152587890625
# 0.000762939453125
# 0.0003814697265625
# 0.00019073486328125
# 9.5367431640625e-05
# 4.76837158203125e-05
# 2.384185791015625e-05
# 1.1920928955078125e-05
# 5.9604644775390625e-06
# 2.9802322387695312e-06
# 1.4901161193847656e-06
# 7.450580596923828e-07
# 3.725290298461914e-07
# 1.862645149230957e-07
# 9.313225746154785e-08
# 4.6566128730773926e-08
# 2.3283064365386963e-08
# 1.1641532182693481e-08
# 5.820766091346741e-09
# 2.9103830456733704e-09
# 1.4551915228366852e-09
# 7.275957614183426e-10
# 3.637978807091713e-10
# 1.8189894035458565e-10
# 9.094947017729282e-11
# 4.547473508864641e-11
# 2.2737367544323206e-11
# 1.1368683772161603e-11
# 5.6843418860808015e-12
# 2.8421709430404007e-12
# 1.4210854715202004e-12
# 7.105427357601002e-13
# 3.552713678800501e-13
# 1.7763568394002505e-13
# ...

# %%
print(1234)
# Out:
# 1234

# %%
print('Hello,World')
# Out:
# Hello,World

# %%
print("Hello,World")
# Out:
# Hello,World

# %%
print('Hello",World')
# Out:
# Hello",World

# %%
print("hello',world")
# Out:
# hello',world

# %%
print("hello\",world")
# Out:
# hello",world

# %%
str('hello world')
# Out:
# 'hello world'

# %%
x=12.2
y=14
x=100

# %%
x=12
x
# Out:
# 12

# %%
x=0.6
x=3.9*x*(1-x)
x
# Out:
# 0.9359999999999999

# %%
4%3
# Out:
# 1

# %%
9**3
# Out:
# 729

# %%
x=2
x=1+2**3/4*5
x
# Out:
# 11.0

# %%
x=1+2
x
# Out:
# 3

# %%
x='1'+'2'
x
# Out:
# '12'

# %%
type(x)
# Out:
# str

# %%
x=12

# %%
type(x)
# Out:
# int

# %%
3/4
# Out:
# 0.75

# %%
x='1'+'2'
x
# Out:
# '12'

# %%
x='12'
y=5
int(x)+y
# Out:
# 17

# %%
type(x)
type(x)
# Out:
# str

# %%
1+3.0
# Out:
# 4.0

# %%
1+3
# Out:
# 4

# %%
x=3.0+1
type(x)
# Out:
# float

# %%
x=4
float(x)
# Out:
# 4.0

# %%
x='sgan'
int(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-6f060e214319> in <module>
#       1 x='sgan'
# ----> 2 int(x)
#
# ValueError: invalid literal for int() with base 10: 'sgan'

# %%
2+3
# Out:
# 5

# %%
name=input('What is your name?')
print('My name is',name)
# Out:
# What is your name?Sagan
# My name is Sagan

# %%
numb=input('Whats your Roll number ')
print("My roll number is ",numb)
print("The next student roll number is ",int(numb)+1)
# Out:
# Whats your Roll number 9
# My roll number is  9
# The next student roll number is  10

# %%
eu=input('europe floor ')
print('US floor: ',int(eu)+1)
# Out:
# europe floor 3
# US floor:  4
